# %%
import torch 
import torchaudio
from IPython.display import Audio
from utils import ProcessPipe
from matplotlib import pyplot as plt
import numpy as np

# %%
waveform1, sample_rate1 = torchaudio.load("../data/train_audio/lessts1/XC251852.ogg")

# %%
length=32000*5

# %%
rand=np.random.randint(0,waveform1.shape[1]-length)

# %%
waveform1=waveform1[:,rand:rand+length]

# %%
Audio(waveform1,rate=32000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
preprocessor=ProcessPipe(32000,15340,384)

# %%
test=preprocessor(waveform1,aug=False)

# %%
plt.imshow(test.squeeze(0))

# %%
test.shape
# Out:
# torch.Size([1, 384, 384])
